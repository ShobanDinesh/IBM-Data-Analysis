# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from scipy import stats

# %%
path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# It is important to understand what type of variable we are dealing, before visualize individual variables.

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %% [markdown]
# #### Continous numerical varaibles

# %%
sns.regplot(x='engine-size',y='price',data=df)
plt.ylim(0,)
# Out:
# (0, 56021.173553955814)

# %%
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# It can be noted that engine size and price have a positive linear relationship, as the engine size increase, so does the price. The correlation between the variables are 0.87. Engine size can be a great predictor of price

# %%
sns.regplot(x='highway-mpg',y='price',data=df)

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# Highway mpg and price have an inverse/negative relatioship, the correlation coefficient is -0.7. Highway mpg could be a potential predictor of price

# %%
sns.regplot(x='peak-rpm',y='price',data=df)

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
# It is evident that the peak rpm and price have weak linear relationship with correlation coefficient of -0.1, it is not a great predictor of price

# %%
sns.regplot(x='stroke',y='price',data=df)

# %%
df[['stroke','price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %% [markdown]
# #### Categorical Variable

# %%
sns.boxplot(data=df,x='body-style',y='price')

# %% [markdown]
# We can see that distribution of price between different types of body types have a significant overlap, so body style may noy be a great predictor

# %%
sns.boxplot(x='engine-location',y='price',data=df)

# %% [markdown]
# Here we see the clear distinction in the distribution of price between the two engine location, can be seen as a potential predictor

# %%
sns.boxplot(data=df,x='drive-wheels',y='price')

# %% [markdown]
# Here we see that the distribution of price between the different drive-wheels categories differs; as such drive-wheels could potentially be a predictor of price.

# %% [markdown]
# #### Descriptive Statistics

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
drive_wheels_df = df['drive-wheels'].value_counts().to_frame()
drive_wheels_df.rename(columns={'drive-wheels':'value_counts'},inplace=True)
drive_wheels_df
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location':'value_counts'},inplace=True)
engine_loc_counts
# Out:
#        value_counts
# front           198
# rear              3

# %% [markdown]
# We can notice that 'rear' engine location data appears only 3 times in the dataset, hence engine location will not be a good predictor as the results might be askewed

# %% [markdown]
# #### Basics of grouping
# Suppose we want to know, which drive wheel type is the most valuable on average

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one = df[['drive-wheels','price']]

# %%
df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# We can see that rear wheel drive types is the most expensive of the 3 types, while the other two are almost in the same range

# %%
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test_1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test_1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# It is easier to visualize grouped data when put in a pivot table. Pivot table is an Excel spreadsheet where the one varaible is along the column where the other is along the row.

# %%
grouped_pivot = grouped_test_1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# Sometimes we wont get all the data in the pivot table, we can fill it with potential values

# %%
grouped_pivot = grouped_pivot.fillna(0)

# %%
grouped_test_2 = df[['body-style','price']]
grouped_test_bodystyle = grouped_test_2.groupby(['body-style'],as_index=False).mean()
grouped_test_bodystyle
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %% [markdown]
# Heatmap to visualize the relationship between body style and price.
# Heatmap will plot the target variable(price) proportional to color with respect tothe varibles 'drive-wheels' and 'body-style' in the vertical and horizontal axis respectively.

# %%
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %% [markdown]
# #### Correlation and Causation
# Correlation is a measure of extent of interdependence of variables
#
# Causation is the relationship of cause and effect between two variables
#
# "Correlation does not imply Causation"
#
# Determining Correlation is much easier then determining causation, as causation might require independent experiment
#
# Pearson's Correlation measures the linear dependence between two variables. It varies from -1 to 1, where -1 represents total negative correlation, 0 represents no linear correlation, 1 represents total positive correlation

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# P-value: P-value is the probability value that the correlation between 2 variables is statistically significant. Normally, we choose the significance value of 0.05, which means we are 95% confident that the correlation is significant.
# By convention, when the
# <ul>
#     <li>p-value < 0.001, we can say that the strong evidence that the correlation is significant </li>
#     <li>p-value < 0.05, we can say that the moderate evidence that the correlation is significant </li>
#     <li>p-value < 0.1, we can say that the weak evidence that the correlation is significant </li>
#     <li>p-value > 0.1, we can say that the no evidence that the correlation is significant </li>
# </ul>

# %%
def corr_p(col_1,col_2='price'):
    p_cor, p_value = stats.pearsonr(df[col_1],df[col_2])
    evidence = ''
    correlation = ''
    if p_value<0.001:
        evidence = 'strong'
    elif p_value<0.05:
        evidence = 'moderate'
    elif p_value<0.1:
        evidence = 'weak'
    else:
        evidence = 'no'
    print(p_cor,'correlation with',evidence,'evidence')

# %%
corr_p('wheel-base')
# Out:
# 0.5846418222655081 correlation with strong evidence

# %%
corr_p('length')
# Out:
# 0.690628380448364 correlation with strong evidence

# %%
corr_p('width')
# Out:
# 0.7512653440522674 correlation with strong evidence

# %%
corr_p('curb-weight')
# Out:
# 0.8344145257702846 correlation with strong evidence

# %%
corr_p('engine-size')
# Out:
# 0.8723351674455185 correlation with strong evidence

# %%
corr_p('bore')
# Out:
# 0.5431553832626602 correlation with strong evidence

# %%
corr_p('city-mpg')
# Out:
# -0.6865710067844677 correlation with strong evidence

# %%
corr_p('highway-mpg')
# Out:
# -0.7046922650589529 correlation with strong evidence

# %% [markdown]
# #### ANOVA
# The Analysis of Variance is a statistical method used to test if there are significant difference between the mean of 2 or more groups. ANOVA returns 2 parameters:
# <ul>
#     <li>F test score: ANOVA assumes that the means of all groups are the same, calculated how the actual mean deviates from the assumption and reports it as F test score. A larger score means there is larger difference between them.</li>
#     <li>P-value tells how statistically significant the calculated value is.</li>
# </ul>
# If price is strongly correlated with a variable, we can expect ANOVA to return sizeable F test score and small p value

# %%
grouped_df = df[['drive-wheels','price']].groupby(['drive-wheels'])

# %%
f_val, p_val = stats.f_oneway(grouped_df.get_group('fwd')['price'],grouped_df.get_group('rwd')['price'],grouped_df.get_group('4wd')['price'])

# %%
f_val,p_val
# Out:
# (67.95406500780399, 3.3945443577151245e-23)

# %% [markdown]
# This is a great result, with a large F test score showing a strong correlation and a P value of almost 0 implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated?

# %%
f_val, p_val = stats.f_oneway(grouped_df.get_group('fwd')['price'], grouped_df.get_group('rwd')['price'])  
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %%
f_val, p_val = stats.f_oneway(grouped_df.get_group('4wd')['price'], grouped_df.get_group('rwd')['price'])  
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %%
f_val, p_val = stats.f_oneway(grouped_df.get_group('4wd')['price'], grouped_df.get_group('fwd')['price'])  
print("ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666

# %% [markdown]
# <p>We now have a better idea of what our data looks like and which variables are important to take into account when predicting the car price. We have narrowed it down to the following variables:</p>
#
# Continuous numerical variables:
# <ul>
#     <li>Length</li>
#     <li>Width</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Horsepower</li>
#     <li>City-mpg</li>
#     <li>Highway-mpg</li>
#     <li>Wheel-base</li>
#     <li>Bore</li>
# </ul>
#
# Categorical variables:
# <ul>
#     <li>Drive-wheels</li>
# </ul>
#
# <p>As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.</p>
